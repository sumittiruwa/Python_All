# %%
import numpy as np

# %%
print("hello , world")
# Out:
# hello , world

# %%
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import sklearn
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import sklearn
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
l = 45

# %%
print(7)
# Out:
# 7
