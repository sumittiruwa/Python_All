# %%
import numpy as np

# %%
myarr = np.array([[2,3,56,7]], np.int64)

# %%
myarr[0,1]
# Out:
# np.int64(3)

# %%
  myarr.shape
# Out:
# (1, 4)

# %%
myarr.dtype
# Out:
# dtype('int64')

# %%
#Array creation : conversion from  other structures

# %%
listarray = np.array([[1,2,3],[4,5,6]])

# %%
listarray

# %%
listarray.shape

# %%
listarray.all

# %%
np.array([1,2,3], dtype=np.float64)
